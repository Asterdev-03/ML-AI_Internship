# %% [markdown]
# ## Aswin K
# ## Data visualisation - activity 1 - Batch3- ML and AI internship

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # auto-mpg

# %%
file1 = pd.read_csv('auto-mpg.csv')

# %%
file1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
plt.figure(figsize=(10,5))
plt.hist(file1['mpg'],color='cyan',rwidth=0.9,density=True)
plt.title('Distribution of MPG')
plt.xlabel('MPG')
plt.ylabel('Frequency')
file1['mpg'].plot.kde(color = 'blue')
# Out:
# <AxesSubplot:title={'center':'Distribution of MPG'}, xlabel='MPG', ylabel='Density'>

# %%
file1[['weight','acceleration']].plot.hist(rwidth = 0.8)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(figsize=(10,5))
plt.scatter(file1['horsepower'],file1['mpg'],s=12,c='lime',marker='+')
plt.title('Plot of Weight vs Acceleration',fontsize=15)
plt.xlabel('Weight')
plt.ylabel('Acceleration')
# Out:
# Text(0, 0.5, 'Acceleration')

# %%
file=file1.drop([32,126, 330, 336, 354, 374])
file['horsepower']=file['horsepower'].astype(float)

# %%
file
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
file[['weight','acceleration']].plot.hist(rwidth = 0.8)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(figsize=(10,5))
plt.scatter(file['horsepower'],file['mpg'],s=12,c='lime',marker='+')
plt.title('Plot of Weight vs Acceleration',fontsize=15)
plt.xlabel('Weight')
plt.ylabel('Acceleration')
# Out:
# Text(0, 0.5, 'Acceleration')

# %%
file1.plot(figsize = (10,5))
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(file1)

# %% [markdown]
# ## iris

# %%
file2 = pd.read_excel('iris.xls')

# %%
file2
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.figure(figsize=(10,5))
plt.hist(file2['SL'],color = 'cyan',rwidth=.8,density=True)
plt.title('Distribution of SL',fontsize=16)
plt.xlabel('SL')
plt.ylabel('Frequency')
file2['SL'].plot.kde(color = 'blue')
# Out:
# <AxesSubplot:title={'center':'Distribution of SL'}, xlabel='SL', ylabel='Density'>

# %%
file2[['SL','PL']].plot.hist(rwidth = 0.8)
file2[['SL','PL']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure(figsize=(5,5))
plt.hist(file2['SW'],color = 'cyan',rwidth=.8,density=True)
plt.title('Distribution of SW',fontsize=16)
plt.xlabel('SW')
plt.ylabel('Frequency')
file2['SW'].plot.kde(color = 'blue')
# Out:
# <AxesSubplot:title={'center':'Distribution of SW'}, xlabel='SW', ylabel='Density'>

# %%
file2[['SW','PW']].plot.hist(rwidth = 0.8)
file2[['SW','PW']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
file2.plot(figsize = (10,5))
# Out:
# <AxesSubplot:>
