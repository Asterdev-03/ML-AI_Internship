# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file1 = pd.read_csv('auto-mpg.csv')

# %%
file2 = pd.read_excel('iris.xls')

# %%
file1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
file2
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.figure()
plt.hist(file1['displacement'],rwidth = 0.9,density = True)
plt.title('PLOT OF MPG')
plt.xlabel('mpg')
plt.ylabel('frequency')
plt.xticks()
plt.yticks()
# Out:
# (array([0.   , 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.scatter(file1['mpg'],file1['displacement'],marker = '*',c = 'red',s =10)

# %%
sns.pairplot(file1)

# %%
plt.boxplot(file1['displacement'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24e1da3cdf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24e1da484f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24e1da3caf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x24e1da48b80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24e1da48eb0>],
#  'means': []}

# %%
file1['displacement'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
file1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
file1[['mpg','displacement']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
file1[['mpg','displacement']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
file1[['mpg','horsepower']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# file1[['mpg','horsepower']].plot.kde()
